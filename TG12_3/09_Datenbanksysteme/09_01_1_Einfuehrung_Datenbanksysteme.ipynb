# %% [markdown]
# # Datenbanksysteme
#
# ## Einführung
#
# ### Fragen zum Videoimpuls
#
# ---
# ---
# #### **🧠 1. Einstieg / Überblick**
#
# 1.1 **Beschreibe** die Ziele des Kurses in eigenen Worten.
# - Aufbau und Benutzung von Datenbankenmanagemantsystemen verstehen.
#
# 1.2 **Nenne** die wichtigsten Themenbereiche des Kurses.
# - Datenbanken, vor allem renationale Datenbankenmanagemantsystemen.
#
# 1.3 **Ordne** die folgenden Begriffe in die richtige Reihenfolge:
# - ER-Modell
# - SQL
# - Relationales Modell
# ---
#
#
# #### **🧩 2. Modellierung verstehen**
#
# 2.1 **Beschreibe** das Beispiel „Mitarbeiter – Projekt“.
# - Ein Mitarbeiter hat die Eigenschaften Vorname, Nachname und Alter. Ein Projekt hat die Eigenschaften Name, Kunde und Budget.
# - Der Mitarbeiter und das Projekt haben bestimmte Beziehungen.
# - Ein Mitarbeiter arbeitet höchstens an einem Projekt. An einem Projekt können mehrere Mitarbeiter arbeiten.
#
# 2.2 **Bestimme** die Kardinalität der Beziehung und **begründe** deine Entscheidung.
# - Ein Mitarbeiter kann höchstens in einem Projekt arbeitern. Die Kardinalität ist 1.
# - Ein Projekt kann mehrere Mitarbeiter haben. Die Kardinalität ist n.
#
# 2.3 **Erkläre**, warum man Daten zuerst modelliert und nicht direkt programmiert.
# - Weil es die Grundlage ist, und damit man die Beziehungen der Objekte besser verstehen.
# ---
#
# #### **🏗️ 3. Relationales Modell**
#
# 3.1 **Erläutere**, wie aus einem ER-Diagramm Tabellen entstehen.
# - Man erstellt eine Tabelle mit dem Namen des Objkektes, und schreibt die Eigenschaften hinein.
# - Man schreibt in SQL, wie man eine Tabelle hinzufügt (CREATE TABLE) und übergibt die Eigenschaften.
#
# 3.2 **Beschreibe** die Bedeutung von:
#
# - Primärschlüssel:
# - Ein Primärschlüssen ist, wenn ein Attribut ganz eindeutig zugeordnet identifiziert ist.
#
# - Fremdschlüssel:
# - Ein Fremdschlüssen ist, wenn ein Attribut auf ein anderes Schlüsselattribut in einer anderen Tabelle zeigt.
#
# 3.3 **Erkläre**, warum Beziehungen in Tabellen dargestellt werden müssen.
# - Mann muss Beziehungen darstellen, um zu wissen, was bei Änderungen passiert.
# ---
#
# #### **⚙️ 4. Integrität und Datenqualität**
#
# 4.1 **Nenne** Maßnahmen zur Sicherstellung der Datenintegrität.
# - Man muss Datentypen nennen.
# - Man kann Rechte vergeben, also wer was auf welcher Tabelle ausführen darf.
# - Man kann bestimmen welche Transaktionen man auf den Tabellen durchführen kann, also wie wir Daten einfügen oder ändern und was dann passiert.
#
#
# 4.2 **Erkläre**, warum fehlerhafte Daten problematisch sind.
# - Weil dann unklar ist, was mit den Werten passiert.
#
#
# 4.3 **Gib** ein Beispiel für eine Verletzung der Integrität.
# - Wenn beispielsweise ein Projekt gelöscht wird, indem noch Mitarbeiter arbeiten, ist unklar was mit den Werten passiert.
# ---
#
# #### **🧮 5. SQL und Anfragen**
#
# 5.1 **Erkläre**, was „deklarative Anfrage“ bedeutet.
# - Man programmiert nicht "Wie erzeuge ich ein Anfrageergebnis?", so wie in anderen Programmiersprachen, sondern man programmiert "Was soll im Anfrageergebnis stehen?".
#
# 5.2 **Beschreibe** den Unterschied zwischen:
#
# - natürlicher Sprache:
# - Die natürliche Sprache ist, wie wir Menschen immer in Worten sprechen.
#
# - relationaler Algebra:
# - Die relationale Algebra ist in mathematischen und griechischen Buchstaben ausgedrückt (Theoretische Ebene).
#
# - SQL:
# - SQL ist der formulierte Programmcode, welcher ausdrückt, was man sehen möchte (Praktische Ebene).
#
# 5.3 **Formuliere** eine einfache SQL-Anfrage in eigenen Worten (ohne Syntax).
# - Zeige alle Mitarbeiter die in einem bestimmten Projekt arbeiten.
# ---
# ---

# %% [markdown]
# ### SQL Island
# Spiele [SQL Island](https://sql-island.informatik.uni-kl.de) und notiere alle erzeugten Befehle in der MS SQL-Zelle.

# %% [markdown]
# ---
# 1.

# %%
SELECT * FROM DORF

# %% [markdown]
# ---
# 2.

# %%
SELECT * FROM BEWOHNER

# %% [markdown]
# ---
# 3.

# %%
SELECT * FROM bewohner WHERE beruf = 'Metzger'

# %% [markdown]
# ---
# 4.

# %%
SELECT * FROM BEWOHNER WHERE status = 'friedlich'

# %% [markdown]
# ---
# 5.

# %%
SELECT * FROM BEWOHNER WHERE status = 'friedlich' AND beruf = 'Waffenschmied'

# %% [markdown]
# ---
# 6.

# %%
SELECT * FROM BEWOHNER WHERE status = 'friedlich' AND beruf LIKE '%schmied'

# %% [markdown]
# ---
# 7.

# %%
INSERT INTO bewohner (name, dorfnr, geschlecht, beruf, gold, status) VALUES ('Fremder', 1, '?', '?', 0, '?')

# %% [markdown]
# ---
# 8.

# %%
SELECT bewohnernr FROM BEWOHNER WHERE name = 'Fremder'

# %% [markdown]
# ---
# 9.

# %%
SELECT gold FROM BEWOHNER WHERE name = 'Fremder'

# %% [markdown]
# ---
# 10.

# %%
SELECT * FROM GEGENSTAND WHERE besitzer IS NULL

# %% [markdown]
# ---
# 11.

# %%
UPDATE gegenstand SET besitzer = 20 WHERE gegenstand = 'Kaffeetasse'

# %% [markdown]
# ---
# 12.

# %%
UPDATE gegenstand SET besitzer=20 WHERE besitzer IS NULL

# %% [markdown]
# ---
# 13.

# %%
SELECT * FROM GEGENSTAND WHERE besitzer IS 20

# %% [markdown]
# ---
# 14.

# %%
SELECT * FROM BEWOHNER WHERE (status = 'friedlich') AND (beruf = 'Haendler') OR (beruf = 'Kaufmann')

# %% [markdown]
# ---
# 15.

# %%
UPDATE gegenstand SET besitzer = 15 WHERE (gegenstand = 'Ring') OR (gegenstand = 'Teekanne')

# %% [markdown]
# ---
# 16.

# %%
UPDATE bewohner SET gold = gold + 120 WHERE bewohnernr = 20

# %% [markdown]
# ---
# 17.

# %%
UPDATE BEWOHNER SET name = 'Sofia Jäger' WHERE name = 'Fremder'

# %% [markdown]
# ---
# 18.

# %%
SELECT * FROM BEWOHNER WHERE beruf = 'Baecker' ORDER BY gold DESC

# %% [markdown]
# ---
# 19.

# %%
UPDATE bewohner SET gold = gold + 100 - 150 WHERE bewohnernr = 20

# %% [markdown]
# ---
# 20.

# %%
INSERT INTO gegenstand (gegenstand, besitzer) VALUES ('Schwert', 20)

# %% [markdown]
# ---
# 21.

# %%
SELECT * FROM BEWOHNER WHERE beruf = 'Pilot'

# %% [markdown]
# ---
# 22.

# %%
SELECT dorf.name FROM dorf, bewohner WHERE dorf.dorfnr = bewohner.dorfnr AND bewohner.name = 'Dirty Dieter'

# %% [markdown]
# ---
# 23.

# %%
SELECT BEWOHNER.name FROM DORF, BEWOHNER WHERE DORF.name = 'Zwiebelhausen' AND BEWOHNER.bewohnernr = Haeuptling

# %% [markdown]
# ---
# 24.

# %%
SELECT COUNT(*) FROM bewohner, dorf WHERE dorf.dorfnr = bewohner.dorfnr AND dorf.name = 'Zwiebelhausen'

# %% [markdown]
# ---
# 25.

# %%
SELECT COUNT(*) FROM BEWOHNER, DORF WHERE DORF.dorfnr = BEWOHNER.dorfnr AND BEWOHNER.geschlecht = 'w' AND DORF.name = 'Zwiebelhausen'

# %% [markdown]
# ---
# 26.

# %%
SELECT BEWOHNER.name FROM BEWOHNER, DORF WHERE DORF.dorfnr = BEWOHNER.dorfnr AND BEWOHNER.geschlecht = 'w' AND DORF.name = 'Zwiebelhausen'

# %% [markdown]
# ---
# 27.

# %%
SELECT SUM(bewohner.gold) FROM bewohner, dorf WHERE dorf.dorfnr = bewohner.dorfnr AND dorf.name = 'Gurkendorf'

# %% [markdown]
# ---
# 28.

# %%
SELECT SUM(gold) FROM Bewohner WHERE beruf IN("Kaufmann", "Haendler", "Baecker")

# %% [markdown]
# ---
# 29.

# %%
SELECT beruf, SUM(bewohner.gold), AVG(bewohner.gold) FROM bewohner GROUP BY beruf ORDER BY AVG(bewohner.gold)

# %% [markdown]
# ---
# 30.

# %%
SELECT status,  AVG(bewohner.gold) FROM bewohner GROUP BY status ORDER BY AVG(bewohner.gold)

# %% [markdown]
# ---
# 31.

# %%
DELETE FROM bewohner WHERE name = 'Dirty Dieter'

# %% [markdown]
# ---
# 32.

# %%
DELETE FROM bewohner WHERE name = 'Dirty Dörthe'

# %% [markdown]
# ---
# 33.

# %%
UPDATE Bewohner SET status = 'friedlich' WHERE bewohnernr = 8

# %% [markdown]
# ---
# 34.

# %%
UPDATE bewohner SET status = 'ausgewandert' WHERE bewohnernr = 20

# %% [markdown]
# ---
# ---
# ## SELECT-Befehle
#
# **Schreibe alle Unterbefehle von SELECT auf (rot makiert).**
#
# |Befehl|Erläuterung|
# |---|---|
# FROM|        - *Auswahl von Tabellen*
# WHERE|       - *Eingrenzen der auszugebenen Zeilen*
# GROUP BY|    - **
# ORDER BY|    - *Sortieren der Zeilen*
#     DESC|    - *(descending) Absteigende Sortierung*
#     ASC|     - *(ascending) Aufsteigende Sortierung*
# |
#
# LIKE|        - *Vergleich Text mit Muster, z.B. name LIKE 'ma%'*
# AND         - *Abfrage mit mehreren Bedingungen, z.B. name LIKE 'ma%' AND status LIKE 'friedlich'*
# OR          - *Abfrage mit mehreren Bedingungen, z.B. name LIKE 'ma%' OR status LIKE 'friedlich'*
# COUNT       - **
# SUM         - **
# AVG         - **
# IS NULL     - *Abfrage, ob ein Attribut keinen Wert hat*
# IN          - *Abfrage, ob der Wert des Attributes in einer Liste vorkommt*
#
# ---
#
# UPDATE      - *Ändert Daten von Zeilen*
# DELETE      - *Löscht Zeilen*

# %% [markdown]
# ---
# ---
# ## Genauere Erläuterungen/ Beispiel
#
# ![TabelleDorf](Bilder/Tabelle_dorf.jpeg)
# ![TabelleBewohner](Bilder/Tabelle_bewohner.jpeg)

# %%
SELECT Dorf.dorfnr, Bewohner.bewohnernr
FROM Dorf, Bewohner
WHERE Dorf.dorfnr = Bewohner.dorfnr

# %% [markdown]
# |Dorf.dorfnr|Bewohner.bewohnernr|
# |:---:|:---:|
# **1**|**1**
# ~~1~~|~~2~~
# **1**|**3**
# |
# ~~2~~|~~1~~
# ~~2~~|~~2~~
# ~~2~~|~~3~~
# |
# ~~3~~|~~1~~
# **3**|**2**
# ~~3~~|~~3~~
