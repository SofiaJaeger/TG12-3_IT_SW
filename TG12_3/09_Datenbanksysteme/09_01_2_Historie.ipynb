# %% [markdown]
# # Datenbanksysteme
#
# ## Historie
#
# ### Fragen zum Videoimpuls
#
#
# #### 🧠 1. Entwicklungslinien von Datenbanksystemen
#
# 1.1 Erkläre den Unterschied zwischen:
#
# - hierarchischem Modell
# - Netzwerkmodell
#
# 1.2 Erläutere, warum die Trennung zwischen physischer und konzeptioneller Ebene früher problematisch war.  ￼
#
# 1.3 Erkläre, was mit „deklarativer DML“ gemeint ist.
#
# 1.4 Begründe, warum sich Datenbanksysteme im Laufe der Zeit verändert haben.
#
# #### 🏗️ 2. Frühe Datenbanksysteme
#
# 2.1 Beschreibe die Eigenschaften früher Dateisysteme (Anfang 1960er Jahre).
#
# 2.2 Erkläre, warum diese Systeme:
#
# - redundant
# - inkonsistent
#
# waren.  ￼
#
# 2.3 Vergleiche:
#
# - Dateiverwaltungssysteme
# - moderne Datenbanksysteme
#
# #### 🔄 3. Einsatzgebiete von Datenbanksystemen
#
# 3.1 Erkläre, warum gleichzeitiger Zugriff (Nebenläufigkeit) wichtig ist.
#
# 3.2 Erläutere, warum Konsistenz bei Banksystemen besonders wichtig ist.
#
# #### 🧮 4. Relationale Datenbanken
#
# 4.1 Beschreibe die zentralen Eigenschaften relationaler Datenbanken.
#
# 4.2 Erkläre, warum sie als Fortschritt gegenüber älteren Systemen gelten.  ￼
