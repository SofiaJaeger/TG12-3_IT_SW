# %% [markdown]
# # Übung
#
# Wir werden demnächst die Ballbewegungen während eines Fußballspiels simulieren. Dazu werden wir Spieler mit individuellen Eigenschaften beschreiben. Auf dessen Grundlage können Pässe, Torschüsse, Einwürfe, Abstösse simuliert werden. Wo ist der Ball nach einer Aktion: beim Gegner, beim Mitspieler, im Tor, im Aus...
#
# Für einen Spieler sollen die folgenden Angaben gespeichert werden:
# - name
# - jahrgang
# - staerke
# - torschuss
# - motivation
#
# Stärke, Torschuss und Motivation sollen einen natürlichen Wert zwischen 1 (schlecht) und 10 (sehr gut) haben. Der Konstruktur bekommt zu allen Attributen einen Wert übergeben.
#
# ## Aufgabe 1
# Erstellen Sie ein Klassendiagramm zur Klasse `Spieler`. Legen Sie Attributnamen, Datentypen, Sichtbarkeit und Zusicherungen fest. Nutzen Sie dazu die Erweiterung UMLet (siehe unten).
#
# ## Aufgabe 2
# Erstellen Sie in python die Klasse `Spieler`.

# %% [markdown]
# # Exkurs UMLet
# Die Erweiterung UMLet in Visual Studio Code dient dazu, UML-Diagramme (z. B. Klassendiagramme, Sequenzdiagramme, Zustandsdiagramme usw.) direkt in VS Code zu erstellen und zu bearbeiten.
#
# -	UMLet – UML Tool for Fast UML Diagrams
# -	Unterstützt UMLet .uxf-Dateien, die man auch in der Desktop-App UMLet öffnen kann.
# -	Diagramme können als Bild (PNG, SVG, PDF) exportiert werden.
#
# ## Verwendung in VS Code:
# 1.	Erweiterung „UMLet“ installieren.
# 2.	Eine Datei mit der Endung .uxf oder .uml öffnen oder neu erstellen.
# 3.	Im Textbereich das UMLet-Format eingeben (z. B. für eine Klasse).
# 4.	Das Diagramm wird automatisch in einer Vorschau angezeigt.

# %%
import datetime as dt

class Spieler():

    #-------------------FUNKTIONEN-------------------

    #-------------------INIT-------------------
    def __init__(self, name:str, jahrgang:int, staerke:int, torschuss:int, motivation:int):
        self.name:str = name
        self.jahrgang:int = jahrgang
        self.staerke:int = staerke
        self.toschuss:int = torschuss
        self.motivation:int = motivation

    #-------------------ZUSICHERUNGEN-------------------

    #-------------------NAME-------------------
    def __set_zusicherungswert_name(self, name:str) -> None:

        if len(name) < 1:
            raise ValueError("Der Name muss mindestens aus einem Zeichen bestehen!")
        self.name_mit_zusicherung = name
    

    #-------------------JAHRGANG-------------------
    def __set_zusicherungswert_jahrgang(self, jahrgang:int) -> None:

        aktuelles_datum = dt.date.today()
        aktuelles_jahr = aktuelles_datum.strftime("%Y")
        alter = aktuelles_jahr - jahrgang

        if (alter < 16) | (alter > 35):
            raise ValueError("Das Alter muss zwischen 16 und 35 Jahren sein!")
        self.jahrgang_mit_zusicherung = jahrgang
    

    #-------------------STAERKE-------------------
    def __set_zusicherungswert_staerke(self, staerke:int) -> None:

        if (staerke < 1) | (staerke > 10):
            raise ValueError("Die Staerke muss zwischen 1 und 10 Punkten sein!")
        self.staerke_mit_zusicherung = staerke
    

    #-------------------TORSCHUSS-------------------
    def __set_zusicherungswert_torschuss(self, torschuss:int) -> None:

        if (torschuss < 1) | (torschuss > 10):
            raise ValueError("Der Torschuss muss zwischen 1 und 10 Punkten sein!")
        self.torschuss_mit_zusicherung = torschuss
    
    
    #-------------------MOTIVATION-------------------
    def __set_zusicherungswert_motivation(self, motivation:int) -> None:

        if (motivation < 1) | (motivation > 10):
            raise ValueError("Die Motivation muss zwischen 1 und 10 Punkten sein!")
        self.motivation_mit_zusicherung = motivation

    # HA klasse fertig
